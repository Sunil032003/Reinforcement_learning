# %% [markdown]
# <a href="https://colab.research.google.com/github/Sunil032003/Reinforcement_learning/blob/main/Monto_carlo_pi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def monte_carlo_pi(num_samples):
  x=np.random.uniform(-1,1,num_samples)
  y=np.random.uniform(-1,1,num_samples)
  distance=x**2+y**2
  inside_circle=distance[distance<=1]
  return 4*len(inside_circle)/num_samples
  return pi_estimate
num_samples=10000

# %%
pi_estimate=monte_carlo_pi(num_samples)
print(f"Estimated value of pi with {num_samples} samples: {pi_estimate}")
x=np.random.uniform(-1,1,num_samples)
y=np.random.uniform(-1,1,num_samples)
plt.figure(figsize=(8,6))
plt.scatter(x,y,c=np.sqrt(x**2 + y**2)<=1, cmap='bwr',s=1)
plt.gca().set_aspect('equal', adjustable='box')
plt.title("Monto carlo simulation of pi")
plt.xlabel("x")
plt.ylabel("y")
plt.show()
# Out:
# Estimated value of pi with 10000 samples: 3.156
